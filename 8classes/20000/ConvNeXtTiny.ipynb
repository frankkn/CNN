# %%
import os
import warnings
warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
from dataclasses import dataclass

import tensorflow as tf
from tensorflow.keras import utils, datasets, layers, models
from tensorflow.keras.applications.convnext import ConvNeXtTiny

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import IPython.display as display
import matplotlib.pyplot as plt

from pathlib import Path

import random
import numpy as np
import matplotlib as mpl

import csv
import pandas as pd
import math
from tqdm import tqdm

import itertools
from collections import defaultdict

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
@dataclass
class ConstParams:
    MODEL_NAME = "ConvNeXtTiny"

@dataclass
class HParams:
    IMAGE_HEIGHT = 300
    IMAGE_WIDTH = 300
    IMAGE_DEPTH = 3
    
    BUFFER_SIZE = 100
    BATCH_SIZE = 64
    
    SEED = 42
    RANDOM_STATE = 42
    
    NUM_EPOCH = 50
    LEARNING_RATE = 1e-5

@dataclass
class Paths:
    DATA_ROOT: Path = Path("./dataset")
    CHECKPOINT_DIR: Path = Path("./checkpoint/" + ConstParams.MODEL_NAME)
    BEST_CHECKPOINT_DIR: Path = Path("./checkpoint/" + ConstParams.MODEL_NAME + "/best")
    # save (img_path, label) pairs
    TRAIN_CSV_PATH: Path = Path("./csv/train.csv")
    VAL_CSV_PATH: Path = Path("./csv/val.csv")
    TEST_CSV_PATH: Path = Path("./csv/test.csv")

# %%
tf.random.set_seed(HParams.SEED)
np.random.seed(HParams.SEED)
random.seed(HParams.SEED)

if not Path("./dataset").exists():
    Path.mkdir(Path("./dataset"))

if not Path("./checkpoint").exists():
    Path.mkdir(Path("./checkpoint"))

if not Path("./csv").exists():
    Path.mkdir(Path("./csv"))

if not Paths.CHECKPOINT_DIR.exists():
    Path.mkdir(Paths.CHECKPOINT_DIR)

if not Paths.BEST_CHECKPOINT_DIR.exists():
    Path.mkdir(Paths.BEST_CHECKPOINT_DIR)

# %%
# print the subfolders.
print('classes:')
for item in Paths.DATA_ROOT.iterdir():
    print(item)
    
all_image_paths = list(Paths.DATA_ROOT.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]
all_image_paths = shuffle(all_image_paths, random_state=HParams.RANDOM_STATE)
# all_image_paths = [path for path in all_image_paths if path[-3:] not in ('gif', 'bmp', 'ini')]
all_image_paths = [path for path in all_image_paths if os.path.splitext(path)[1][1:] in ('jpg', 'JPG')]

image_count = len(all_image_paths)
print('\ntotal img num:', image_count)
# print(f'all image path = {all_image_paths}')
# Out:
# classes:
# dataset\OWNER1_Door Damage
# dataset\OWNER2_Panel dents or scratches
# dataset\OWNER3_Panel aging, rust or breach
# dataset\OWNER4_Placards removal
# dataset\SHIPPER1_Floor stains, contamination or cracks
# dataset\SHIPPER2_Panel or Sidewall protrusion
# dataset\SHIPPER3_Cross member or forklift pocket overweight-deformation
# dataset\SHIPPER4_Panel or Sidewalls dirts
#
# total img num: 20000

# %%
# random showing 3 iamges
for n in range(3):
    image_path = random.choice(all_image_paths)
    display.display(display.Image(image_path, width=200, height=200))
    print(image_path.split('\\')[-2])
    # print(image_path.split(os.path.sep)[-2])
    # print(image_path.split('/')[-2])
# Out:
# SHIPPER3_Cross member or forklift pocket overweight-deformation
# SHIPPER4_Panel or Sidewalls dirts
# OWNER4_Placards removal

# %%
# get the label
label_names = sorted(item.name for item in Paths.DATA_ROOT.glob('*/') if item.is_dir())
# total label
n_classes = len(label_names)
print(label_names)
# Out:
# ['OWNER1_Door Damage', 'OWNER2_Panel dents or scratches', 'OWNER3_Panel aging, rust or breach', 'OWNER4_Placards removal', 'SHIPPER1_Floor stains, contamination or cracks', 'SHIPPER2_Panel or Sidewall protrusion', 'SHIPPER3_Cross member or forklift pocket overweight-deformation', 'SHIPPER4_Panel or Sidewalls dirts']

# %%
# get the mapping dict
label_to_index = dict((name, index) for index,name in enumerate(label_names))
index_to_label = dict((index, name) for index,name in enumerate(label_names))
print(label_to_index)
# Out:
# {'OWNER1_Door Damage': 0, 'OWNER2_Panel dents or scratches': 1, 'OWNER3_Panel aging, rust or breach': 2, 'OWNER4_Placards removal': 3, 'SHIPPER1_Floor stains, contamination or cracks': 4, 'SHIPPER2_Panel or Sidewall protrusion': 5, 'SHIPPER3_Cross member or forklift pocket overweight-deformation': 6, 'SHIPPER4_Panel or Sidewalls dirts': 7}

# %%
# get the label data
all_image_label = [label_to_index[Path(path).parent.name] for path in all_image_paths]
print("First 10 label indices: ", all_image_label[:10])
# Out:
# First 10 label indices:  [7, 2, 3, 3, 1, 3, 2, 4, 7, 0]

# %%
# Create train:val:test datasets using an 80-10-10 split
img_path_train, img_path_val_and_test, label_train, label_val_and_test = train_test_split(all_image_paths, 
                                                                                          all_image_label,
                                                                                          test_size=0.2,
                                                                                          random_state=HParams.RANDOM_STATE)
img_path_val, img_path_test, label_val, label_test = train_test_split(img_path_val_and_test, 
                                                                      label_val_and_test, 
                                                                      test_size=0.5, 
                                                                      random_state=HParams.RANDOM_STATE)


print('training data: %d'%(len(img_path_train)))
print('validation data: %d'%(len(img_path_val)))
print('testing data: %d'%(len(img_path_test)))
# Out:
# training data: 16000
# validation data: 2000
# testing data: 2000

# %%
pairs_ready = False

if pairs_ready != True:
    # save (img_path, label) pairs
    with open(Paths.TRAIN_CSV_PATH, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['img_path', 'label'])
        for img_path, label in zip(img_path_train, label_train):
            writer.writerow([img_path, label])

    with open(Paths.VAL_CSV_PATH, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['img_path', 'label'])
        for img_path, label in zip(img_path_val, label_val):
            writer.writerow([img_path, label])

    with open(Paths.TEST_CSV_PATH, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['img_path', 'label'])
        for img_path, label in zip(img_path_test, label_test):
            writer.writerow([img_path, label])

# %%
class SimpleDataset(tf.data.Dataset):
    OUTPUT_SIGNATURE = (
        tf.TensorSpec(shape=(HParams.IMAGE_HEIGHT, HParams.IMAGE_WIDTH, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(), dtype=tf.int32)
    )

    _INSTANCES_COUNTER = itertools.count()  # Number of datasets generated
    _EPOCHS_COUNTER = defaultdict(itertools.count)  # Number of epochs done for each dataset

    def _generator(instance_idx, filename, open_file, read_file):
        epoch_idx = next(SimpleDataset._EPOCHS_COUNTER[instance_idx])

        # Opening the file
        img_paths, label = open_file(filename)

        # Reading the file
        for sample_idx in range(len(img_paths)):
            img = read_file(img_paths[sample_idx])
            yield img, label[sample_idx]

    def __new__(cls, filename, open_file, read_file):
        def generator_func(instance_idx, filename):
            return cls._generator(instance_idx, filename, open_file, read_file)

        return tf.data.Dataset.from_generator(
            generator_func,
            output_signature=cls.OUTPUT_SIGNATURE,
            args=(next(cls._INSTANCES_COUNTER), filename)
        )

# %%
def open_file(filename):
    rows = pd.read_csv(filename.decode("utf-8"))
    img_paths = rows['img_path'].tolist()
    label = rows['label'].tolist()
    return img_paths, label

def read_file(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=HParams.IMAGE_DEPTH)
    img = tf.image.resize(img, (HParams.IMAGE_HEIGHT, HParams.IMAGE_WIDTH))
    img = tf.cast(img, tf.float32)
    img = tf.divide(img,255.0)
    return img

def dataset_generator_fun_train(*args):
    return SimpleDataset(str(Paths.TRAIN_CSV_PATH), open_file, read_file)

def dataset_generator_fun_val(*args):
    return SimpleDataset(str(Paths.VAL_CSV_PATH), open_file, read_file)

def dataset_generator_fun_test(*args):
    return SimpleDataset(str(Paths.TEST_CSV_PATH), open_file, read_file)

# %%
# parse training data
@tf.function
def map_fun(image, label):
    distorted_image = tf.image.random_flip_left_right(image)
    distorted_image = tf.image.random_brightness(distorted_image, max_delta=60)
    distorted_image = tf.image.random_contrast(distorted_image, lower=0.2, upper=1.8)
    distorted_image = tf.image.per_image_standardization(distorted_image)

    return distorted_image, label

# parse validation data
@tf.function
def map_fun_val(image, label):
    distorted_image = tf.image.per_image_standardization(image)

    return distorted_image, label

# parse testing data
@tf.function
def map_fun_test(image, label):
    distorted_image = tf.image.per_image_standardization(image)

    return distorted_image, label

# %%
dataset_train = tf.data.Dataset.range(1)\
                                .interleave(dataset_generator_fun_train, num_parallel_calls=tf.data.AUTOTUNE)\
                                .shuffle(HParams.BUFFER_SIZE, seed=HParams.SEED)\
                                .batch(HParams.BATCH_SIZE, drop_remainder=True)\
                                .map(map_fun, num_parallel_calls=tf.data.AUTOTUNE)\
                                .cache()\
                                .prefetch(tf.data.AUTOTUNE)

dataset_val = tf.data.Dataset.range(1)\
                                .interleave(dataset_generator_fun_val, num_parallel_calls=tf.data.AUTOTUNE)\
                                .batch(HParams.BATCH_SIZE, drop_remainder=True)\
                                .shuffle(HParams.BUFFER_SIZE, seed=HParams.SEED)\
                                .map(map_fun_val, num_parallel_calls=tf.data.AUTOTUNE)\
                                .cache()\
                                .prefetch(tf.data.AUTOTUNE)

dataset_test = tf.data.Dataset.range(1)\
                                .interleave(dataset_generator_fun_test, num_parallel_calls=tf.data.AUTOTUNE)\
                                .batch(HParams.BATCH_SIZE, drop_remainder=True)\
                                .map(map_fun_test, num_parallel_calls=tf.data.AUTOTUNE)\
                                .cache()\
                                .prefetch(tf.data.AUTOTUNE)

# %%
for img, label in dataset_train.take(1):
    print(img[0].shape)
    plt.imshow(img[0]) 
    plt.axis('off') 
    plt.show()
    print(index_to_label[label[0].numpy()])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (300, 300, 3)
# SHIPPER1_Floor stains, contamination or cracks

# %%
base_model = ConvNeXtTiny(include_top=False,
                   weights='imagenet',
                   input_shape=(HParams.IMAGE_HEIGHT, HParams.IMAGE_WIDTH, HParams.IMAGE_DEPTH),
                   pooling=None
                  )

# 充分利用pre-trained model的特徵提取能力，同時避免在新任務上的overfitting。
for layer in base_model.layers:
    layer.trainable = False

top_model = models.Sequential()
top_model.add(layers.Flatten())
top_model.add(layers.Dense(n_classes, activation='softmax'))

model = tf.keras.Model(inputs=base_model.input, outputs=top_model(base_model.output))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 [==============================] - 33s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  convnext_tiny_prestem_normaliz  (None, 300, 300, 3)  0          ['input_1[0][0]']
#  ation (Normalization)
#
#  convnext_tiny_stem (Sequential  (None, 75, 75, 96)  4896        ['convnext_tiny_prestem_normaliza
#  )                                                               tion[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 96)  4800        ['convnext_tiny_stem[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 96)  192         ['convnext_tiny_stage_0_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 384)  37248      ['convnext_tiny_stage_0_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 384)  0          ['convnext_tiny_stage_0_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 96)  36960       ['convnext_tiny_stage_0_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 96)  96          ['convnext_tiny_stage_0_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_0_block_0_  (None, 75, 75, 96)  0           ['convnext_tiny_stage_0_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 75, 75, 96)  0           ['convnext_tiny_stem[0][0]',
#  da)                                                              'convnext_tiny_stage_0_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 96)  4800        ['tf.__operators__.add[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 96)  192         ['convnext_tiny_stage_0_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 384)  37248      ['convnext_tiny_stage_0_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 384)  0          ['convnext_tiny_stage_0_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 96)  36960       ['convnext_tiny_stage_0_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 96)  96          ['convnext_tiny_stage_0_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_0_block_1_  (None, 75, 75, 96)  0           ['convnext_tiny_stage_0_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 75, 75, 96)  0           ['tf.__operators__.add[0][0]',
#  mbda)                                                            'convnext_tiny_stage_0_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 96)  4800        ['tf.__operators__.add_1[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 96)  192         ['convnext_tiny_stage_0_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 384)  37248      ['convnext_tiny_stage_0_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 384)  0          ['convnext_tiny_stage_0_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 96)  36960       ['convnext_tiny_stage_0_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 96)  96          ['convnext_tiny_stage_0_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_0_block_2_  (None, 75, 75, 96)  0           ['convnext_tiny_stage_0_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 75, 75, 96)  0           ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'convnext_tiny_stage_0_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_downsampling_blo  (None, 37, 37, 192)  74112      ['tf.__operators__.add_2[0][0]']
#  ck_0 (Sequential)
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 192)  9600       ['convnext_tiny_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_0[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 192)  384        ['convnext_tiny_stage_1_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 768)  148224     ['convnext_tiny_stage_1_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 768)  0          ['convnext_tiny_stage_1_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 192)  147648     ['convnext_tiny_stage_1_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 192)  192        ['convnext_tiny_stage_1_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_1_block_0_  (None, 37, 37, 192)  0          ['convnext_tiny_stage_1_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 37, 37, 192)  0          ['convnext_tiny_downsampling_bloc
#  mbda)                                                           k_0[0][0]',
#                                                                   'convnext_tiny_stage_1_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 192)  9600       ['tf.__operators__.add_3[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 192)  384        ['convnext_tiny_stage_1_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 768)  148224     ['convnext_tiny_stage_1_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 768)  0          ['convnext_tiny_stage_1_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 192)  147648     ['convnext_tiny_stage_1_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 192)  192        ['convnext_tiny_stage_1_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_1_block_1_  (None, 37, 37, 192)  0          ['convnext_tiny_stage_1_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 37, 37, 192)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'convnext_tiny_stage_1_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 192)  9600       ['tf.__operators__.add_4[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 192)  384        ['convnext_tiny_stage_1_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 768)  148224     ['convnext_tiny_stage_1_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 768)  0          ['convnext_tiny_stage_1_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 192)  147648     ['convnext_tiny_stage_1_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 192)  192        ['convnext_tiny_stage_1_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_1_block_2_  (None, 37, 37, 192)  0          ['convnext_tiny_stage_1_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 37, 37, 192)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'convnext_tiny_stage_1_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_downsampling_blo  (None, 18, 18, 384)  295680     ['tf.__operators__.add_5[0][0]']
#  ck_1 (Sequential)
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 384)  19200      ['convnext_tiny_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_1[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_0_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_0_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_0_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 18, 18, 384)  0          ['convnext_tiny_downsampling_bloc
#  mbda)                                                           k_1[0][0]',
#                                                                   'convnext_tiny_stage_2_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_6[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_1_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_1_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_1_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 18, 18, 384)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'convnext_tiny_stage_2_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_7[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_2_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_2_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_2_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 18, 18, 384)  0          ['tf.__operators__.add_7[0][0]',
#  mbda)                                                            'convnext_tiny_stage_2_block_2_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_8[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_3_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_3_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_3_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_3_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_3_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_3_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_3_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 18, 18, 384)  0          ['tf.__operators__.add_8[0][0]',
#  mbda)                                                            'convnext_tiny_stage_2_block_3_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_9[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_4_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_4_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_4_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_4_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_4_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_4_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_4_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 18, 18, 384)  0          ['tf.__operators__.add_9[0][0]',
#  ambda)                                                           'convnext_tiny_stage_2_block_4_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_10[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_5_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_5_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_5_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_5_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_5_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_5_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_5_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 18, 18, 384)  0          ['tf.__operators__.add_10[0][0]',
#  ambda)                                                           'convnext_tiny_stage_2_block_5_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_11[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_6_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_6_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_6_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_6_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_6_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_6_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_6_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 18, 18, 384)  0          ['tf.__operators__.add_11[0][0]',
#  ambda)                                                           'convnext_tiny_stage_2_block_6_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_12[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_7_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_7_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_7_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_7_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_7_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_7_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_7_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 18, 18, 384)  0          ['tf.__operators__.add_12[0][0]',
#  ambda)                                                           'convnext_tiny_stage_2_block_7_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 384)  19200      ['tf.__operators__.add_13[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 384)  768        ['convnext_tiny_stage_2_block_8_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 1536  591360     ['convnext_tiny_stage_2_block_8_l
#  pointwise_conv_1 (Dense)       )                                ayernorm[0][0]']
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 1536  0          ['convnext_tiny_stage_2_block_8_p
#  gelu (Activation)              )                                ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 384)  590208     ['convnext_tiny_stage_2_block_8_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 384)  384        ['convnext_tiny_stage_2_block_8_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_2_block_8_  (None, 18, 18, 384)  0          ['convnext_tiny_stage_2_block_8_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 18, 18, 384)  0          ['tf.__operators__.add_13[0][0]',
#  ambda)                                                           'convnext_tiny_stage_2_block_8_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_downsampling_blo  (None, 9, 9, 768)   1181184     ['tf.__operators__.add_14[0][0]']
#  ck_2 (Sequential)
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 768)   38400       ['convnext_tiny_downsampling_bloc
#  depthwise_conv (Conv2D)                                         k_2[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 768)   1536        ['convnext_tiny_stage_3_block_0_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 3072)  2362368     ['convnext_tiny_stage_3_block_0_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 3072)  0           ['convnext_tiny_stage_3_block_0_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 768)   2360064     ['convnext_tiny_stage_3_block_0_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 768)   768         ['convnext_tiny_stage_3_block_0_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_3_block_0_  (None, 9, 9, 768)   0           ['convnext_tiny_stage_3_block_0_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 9, 9, 768)   0           ['convnext_tiny_downsampling_bloc
#  ambda)                                                          k_2[0][0]',
#                                                                   'convnext_tiny_stage_3_block_0_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 768)   38400       ['tf.__operators__.add_15[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 768)   1536        ['convnext_tiny_stage_3_block_1_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 3072)  2362368     ['convnext_tiny_stage_3_block_1_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 3072)  0           ['convnext_tiny_stage_3_block_1_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 768)   2360064     ['convnext_tiny_stage_3_block_1_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 768)   768         ['convnext_tiny_stage_3_block_1_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_3_block_1_  (None, 9, 9, 768)   0           ['convnext_tiny_stage_3_block_1_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 9, 9, 768)   0           ['tf.__operators__.add_15[0][0]',
#  ambda)                                                           'convnext_tiny_stage_3_block_1_i
#                                                                  dentity[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 768)   38400       ['tf.__operators__.add_16[0][0]']
#  depthwise_conv (Conv2D)
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 768)   1536        ['convnext_tiny_stage_3_block_2_d
#  layernorm (LayerNormalization)                                  epthwise_conv[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 3072)  2362368     ['convnext_tiny_stage_3_block_2_l
#  pointwise_conv_1 (Dense)                                        ayernorm[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 3072)  0           ['convnext_tiny_stage_3_block_2_p
#  gelu (Activation)                                               ointwise_conv_1[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 768)   2360064     ['convnext_tiny_stage_3_block_2_g
#  pointwise_conv_2 (Dense)                                        elu[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 768)   768         ['convnext_tiny_stage_3_block_2_p
#  layer_scale (LayerScale)                                        ointwise_conv_2[0][0]']
#
#  convnext_tiny_stage_3_block_2_  (None, 9, 9, 768)   0           ['convnext_tiny_stage_3_block_2_l
#  identity (Activation)                                           ayer_scale[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 9, 9, 768)   0           ['tf.__operators__.add_16[0][0]',
#  ambda)                                                           'convnext_tiny_stage_3_block_2_i
#                                                                  dentity[0][0]']
#
#  layer_normalization (LayerNorm  (None, 9, 9, 768)   1536        ['tf.__operators__.add_17[0][0]']
#  alization)
#
#  sequential (Sequential)        (None, 8)            497672      ['layer_normalization[0][0]']
#
# ==================================================================================================
# Total params: 28,317,800
# Trainable params: 497,672
# Non-trainable params: 27,820,128
# __________________________________________________________________________________________________

# %%
# define loss and optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(HParams.LEARNING_RATE)

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

val_loss = tf.keras.metrics.Mean(name='val_loss')
val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')

# %%
@tf.function
def train_step(image, label):
    with tf.GradientTape() as tape:
        predictions = model(image, training=True)
        loss = loss_object(label, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
#     print("Label shape:", label.shape)
#     print("Predictions shape:", predictions.shape)

    train_loss(loss)
    train_accuracy(label, predictions)
    
@tf.function
def val_step(image, label):
    predictions = model(image, training=False)
    loss = loss_object(label, predictions)

    val_loss(loss)
    val_accuracy(label, predictions)
    
@tf.function
def test_step(image, label):
    predictions = model(image, training=False)
    loss = loss_object(label, predictions)

    return loss, label, predictions

# %%
checkpoint = tf.train.Checkpoint(model=model)
ckpt_manager = tf.train.CheckpointManager(
    checkpoint, Paths.CHECKPOINT_DIR, max_to_keep=3
)
best_manager = tf.train.CheckpointManager(
    checkpoint, Paths.BEST_CHECKPOINT_DIR, max_to_keep=1
)

# %%
train_loss_list = []
val_loss_list = []

def epoch_loop(dataset_train, dataset_test, EPOCHS):
    best_val_acc = 0.
    for epoch in range(EPOCHS):
        print("=" * 10 + f" Epoch {epoch + 1}/{EPOCHS} " + "=" * 10)
        # Reset the metrics at the start of the next epoch
        train_loss.reset_states()
        train_accuracy.reset_states()
        val_loss.reset_states()
        val_accuracy.reset_states()

        tf.print("training:")
        for image, label in tqdm(dataset_train, total=math.floor(len(img_path_train)/HParams.BATCH_SIZE)):
            train_step(image, label)

        tf.print("validating:")
        for image, label in tqdm(dataset_val, total=math.floor(len(img_path_val)/HParams.BATCH_SIZE)):
            val_step(image, label)
            
        train_loss_list.append(train_loss.result().numpy())
        val_loss_list.append(val_loss.result().numpy())
     
        template = 'Epoch {:0}, Training loss: {:.4f}, Training accuracy: {:.4f}, Validation loss: {:.4f}, Validation Accuracy: {:.4f}'
        tf.print (template.format(epoch+1,
                               train_loss.result(),
                               train_accuracy.result()*100,
                               val_loss.result(),
                               val_accuracy.result()*100))
        
        # Save weight after each epoch
        ckpt_manager.save()
        
        # Save best weight
        if val_accuracy.result() > best_val_acc:
            best_val_acc = val_accuracy.result()
            best_manager.save()
            print(f"Best model saved at {best_manager.latest_checkpoint}.")

# %%
epoch_loop(dataset_train, dataset_val, EPOCHS= HParams.NUM_EPOCH)
# Out:
# ========== Epoch 1/50 ==========
# training:
# 100%|████████████████████████████████████████████████████████████████████████████████| 250/250 [52:19<00:00, 12.56s/it]
# validating:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [06:35<00:00, 12.76s/it]
# Epoch 1, Training loss: 1.8488, Training accuracy: 32.8312, Validation loss: 1.5303, Validation Accuracy: 48.7399
# Best model saved at checkpoint\ConvNeXtTiny\best\ckpt-2.
# ========== Epoch 2/50 ==========
# training:
#  23%|██████████████████▊                                                              | 58/250 [13:10<43:35, 13.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 epoch_loop(dataset_train, dataset_val, EPOCHS= HParams.NUM_EPOCH)
#
# Cell In[21], line 16, in epoch_loop(dataset_train, dataset_test, EPOCHS)
#      14 tf.print("training:")
#      15 for image, label in tqdm(dataset_train, total=math.floor(len(img_path_train)/HParams.BATCH_SIZE)):
# ---> 16     train_step(image, label)
#      18 tf.print("validating:")
#      19 for image, label in tqdm(dataset_val, total=math.floor(len(img_path_val)/HParams.BATCH_SIZE)):
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File C:\ProgramData\anaconda3\envs\tf2.11\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
true_label = []
predicted_label = []

def test_loop(dataset_test):
    print(f"Model restored from {tf.train.latest_checkpoint(Paths.BEST_CHECKPOINT_DIR)}.")
    checkpoint = tf.train.Checkpoint(model=model)
    checkpoint.restore(tf.train.latest_checkpoint(Paths.BEST_CHECKPOINT_DIR))
    
    for image, label in tqdm(dataset_test, total=math.floor(len(img_path_test)/HParams.BATCH_SIZE)):
        loss, labels, predictions = test_step(image, label)
        
        true_label.extend(labels.numpy())
        predicted_label.extend(tf.argmax(predictions, axis=1).numpy())
        
        test_loss(loss)
        test_accuracy(labels, predictions)

    template = 'Test loss: {:.4f}, Test accuracy: {:.4f}'
    tf.print(template.format(test_loss.result(), test_accuracy.result()*100))

test_loop(dataset_test)

# %%
# Plot training and validation loss
plt.plot(train_loss_list, label='Training Loss')
plt.plot(val_loss_list, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
cm = confusion_matrix(true_label, predicted_label)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
